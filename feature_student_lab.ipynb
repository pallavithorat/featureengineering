# %% [markdown]
# # Feature Engineering Strategies — Student Lab (Titanic)
#
# Focus: missing data, encoding, nonlinear transforms, and interactions — **leakage-safe**.

# %%
# Feauture engineering is a process of selecting, transforming and creating features from raw data to improve the performance of machine learning models. 
# Feature engineering strategies include:
# 1.data cleaning and preprocessing
# 2.Feature transformation(scaling and normalization)
# 3.Encoding categorical variables
# 4.log/ power transformation
# 5.Binning/ Discretization
# 6.Feature creation
# 7.Feature selection
# 8.Handling missing values/ imbalanced data

import os
import re
import numpy as np
import pandas as pd

from sklearn.model_selection import StratifiedKFold, train_test_split, cross_validate
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, FunctionTransformer
from sklearn.linear_model import LogisticRegression

def check(name: str, cond: bool):
    if not cond:
        raise AssertionError(f'Failed: {name}')
    print(f'OK: {name}')

rng = np.random.default_rng(0)

# %% [markdown]
# ## Section 0 — Load Titanic (Kaggle) with fallback
# Expected: `data/titanic/train.csv`
#
# If missing, a tiny synthetic dataset is used so the notebook runs.

# %%
def load_titanic_or_synthetic():
    path = os.path.join(os.getcwd(), 'data', 'titanic', 'train.csv')
    if os.path.exists(path):
        return 'kaggle', pd.read_csv(path)

    df = pd.DataFrame({
        'Survived': [0,1,1,0,1,0,0,1],
        'Pclass': [3,1,3,3,2,3,2,1],
        'Sex': ['male','female','female','male','female','male','male','female'],
        'Age': [22, 38, np.nan, 35, 28, 2, 54, np.nan],
        'SibSp': [1,1,0,1,0,3,0,0],
        'Parch': [0,0,0,0,0,1,0,0],
        'Fare': [7.25, 71.3, 7.92, 53.1, 13.0, 21.1, 51.9, 30.0],
        'Embarked': ['S','C','S','S',np.nan,'S','S','C'],
        'Cabin': [np.nan, 'C85', np.nan, np.nan, np.nan, np.nan, 'E46', np.nan],
        'Name': [
            'Braund, Mr. Owen Harris',
            'Cumings, Mrs. John Bradley',
            'Heikkinen, Miss. Laina',
            'Allen, Mr. William Henry',
            'Moran, Mr. James',
            'Palsson, Master. Gosta Leonard',
            'McCarthy, Mr. Timothy J',
            'Fortune, Miss. Mabel Helen',
        ],
    })
    return 'synthetic', df

mode, df = load_titanic_or_synthetic()
print('mode', mode, 'rows', len(df))
df.head()
# Out:
# mode synthetic rows 8
#    Survived  Pclass     Sex   Age  SibSp  Parch   Fare Embarked Cabin  \
# 0         0       3    male  22.0      1      0   7.25        S   NaN
# 1         1       1  female  38.0      1      0  71.30        C   C85
# 2         1       3  female   NaN      0      0   7.92        S   NaN
# 3         0       3    male  35.0      1      0  53.10        S   NaN
# 4         1       2  female  28.0      0      0  13.00      NaN   NaN
#
#                          Name
# 0     Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley
# 2      Heikkinen, Miss. Laina
# 3    Allen, Mr. William Henry
# 4            Moran, Mr. James

# %% [markdown]
# ## Section 1 — Baseline pipeline
#
# ### Task 1.1: Train a baseline with leakage-safe preprocessing
#
# Use:
# - Numeric: Age, Fare, SibSp, Parch
# - Categorical: Pclass, Sex, Embarked
#
# # TODO:
# - Create X/y
# - Build ColumnTransformer (impute + scale numeric, impute + one-hot categorical)
# - Evaluate LogisticRegression with StratifiedKFold CV
#
# **Checkpoint:** Why is the pipeline necessary to avoid leakage in CV?

# %%
# Baseline: acts like a reference point for evaluating the performance of more complex models. 
# It is a simple model that provides a benchmark for comparison.or minimal acceptable performance.
# Data leakage issue can be identified early on and can be avoided in future iterations.
# Validate data preprocessing steps and feature engineering techniques

# Components of a baseline model:
# 1. Data preprocessing: handling missing values, encoding categorical variables, scaling features.
# 2. Model selection: choosing a simple model that is easy to implement and interpret.
# 3. Minimal feature engineering: using basic features without complex transformations or interactions.


y = df['Survived'].astype(int) # Target variable
X = df.drop(columns=['Survived']) # drop survived column from the dataset to get the features

numeric_features = ['Age','Fare','SibSp','Parch']
categorical_features = ['Pclass','Sex','Embarked']

# TODO

def make_preprocess(numeric_features, categorical_features):
    return ColumnTransformer(transformers=[
       ('num', Pipeline(steps=[('imputer', SimpleImputer(strategy='median')), ('scaler', StandardScaler())]), numeric_features),
         ('cat', Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')), ('encoder', OneHotEncoder(handle_unknown='ignore'))]), categorical_features),
    ])

preprocess = make_preprocess(numeric_features, categorical_features)

model = LogisticRegression(max_iter=5000)
pipe = Pipeline(steps=[('preprocess', preprocess), ('model', model)])

def cv_acc(pipe, X_df, y_s):
    cv = StratifiedKFold(n_splits=2, shuffle=True, random_state=0)
    scores = cross_validate(pipe, X_df, y_s, cv=cv, scoring={'acc': 'accuracy'})
    return float(scores['test_acc'].mean()), float(scores['test_acc'].std())

cv = StratifiedKFold(n_splits=2, shuffle=True, random_state=0)
scores = cross_validate(pipe, X, y, cv=cv, scoring={'acc': 'accuracy'}, return_train_score=False)
print('baseline acc mean', np.mean(scores['test_acc']))
# Out:
# baseline acc mean 0.75

# %% [markdown]
# ## Section 2 — Missing data: indicators
#
# ### Task 2.1: Add missingness indicator features
#
# Add: Age_is_missing, Cabin_is_missing
#
# # TODO:
# - Create these columns
# - Add them to numeric pipeline
# - Re-run CV and compare
#
# **Checkpoint:** Why can missingness itself be predictive?

# %%
# Missing data: Indicators means creating new binary features that indicate whether a value is missing for a particular feature.
X2 = X.copy()
# TODO
X2['Age_is_missing'] = X2['Age'].isna().astype(int) # isna() returns a boolean Series indicating missing values, astype(int) converts it to 0 and 1
X2['Cabin_is_missing'] = X2['Cabin'].isna().astype(int)

numeric_features2 = numeric_features + ['Age_is_missing','Cabin_is_missing']

# TODO rebuild preprocess and evaluate
preprocess2 = make_preprocess(numeric_features2, categorical_features)
pipe3 = Pipeline(steps=[('preprocess', preprocess2), ('model', LogisticRegression(max_iter=5000))])
scores2 = cross_validate(pipe3, X2, y, cv=cv, scoring={'acc': 'accuracy'})
print('with indicators acc mean', np.mean(scores2['test_acc']))
m3, s3 = cv_acc(pipe3, X2, y)
print('with title acc', m3, 'std', s3)
# Out:
# with indicators acc mean 0.875
# with title acc 0.875 std 0.125

# %% [markdown]
# ## Section 3 — Encoding: One-hot vs Target encoding
#
# ### Task 3.1: Extract Title from Name and one-hot encode
#
# Example titles: Mr, Mrs, Miss, Master.
#
# # TODO:
# - Extract Title with regex
# - Add it as categorical feature
# - Re-run CV

# %%
# Encoding is applied to categorical variables.
# Its a process of categorial var in numeric format so that it can be used by machine learning algorithms.
# One hot encoding
# Target Encoding/likelihood encoding/ mean encoding

def extract_title(name: str):
    if not isinstance(name, str):
        return 'Unknown'
    m = re.search(r',\s*([^\.]*)\.', name)
    return m.group(1).strip() if m else 'Unknown'

X3 = X2.copy()
X3['Title'] = X3['Name'].apply(extract_title)

categorical_features3 = categorical_features + ['Title']
numeric_features3 = numeric_features2

# TODO: preprocess3 + CV
preprocess3 = make_preprocess(numeric_features3, categorical_features3)
pipe3 = Pipeline(steps=[('preprocess', preprocess3), ('model', LogisticRegression(max_iter=5000))])
scores3 = cross_validate(pipe3, X3, y, cv=cv, scoring={'acc': 'accuracy'})
print('with Title acc mean', np.mean(scores3['test_acc']))
# Out:
# with Title acc mean 0.875

# %% [markdown]
# ### Task 3.2: Naive target encoding (demonstrate leakage)
#
# We will *intentionally* do something wrong: compute mean Survived per Title using the full dataset, then map it back.
#
# # TODO:
# - Create Title_target_mean using full data (this is leakage)
# - Compare CV score and explain why it inflates
#
# **Checkpoint:** How do you fix target encoding correctly?

# %%
X4 = X3.copy()
# TODO (leaky)

title_mean = y.groupby(X4['Title']).mean() # groupby Title and calculate mean of target variable for each title
X4['Title_target_mean_leaky'] = X4['Title'].map(title_mean).fillna(y.mean())

numeric_features4 = numeric_features3 + ['Title_target_mean_leaky']
categorical_features4 = categorical_features  # drop Title to keep it purely numeric encoding

preprocess4 = make_preprocess(numeric_features4, categorical_features4)
pipe4 = Pipeline(steps=[('preprocess', preprocess4), ('model', LogisticRegression(max_iter=5000))])
scores4 = cross_validate(pipe4, X4, y, cv=cv, scoring={'acc': 'accuracy'})
print('LEAKY target encoding acc mean', np.mean(scores4['test_acc']))
# Out:
# LEAKY target encoding acc mean 0.75

# %% [markdown]
# ## Section 4 — Nonlinear transforms + binning
#
# ### Task 4.1: Log-transform Fare
#
# # TODO: create Fare_log = log1p(Fare) and evaluate.

# %%
# Non-linear transformation: log/ power transformation is a technique used to transform skewed data into a more normal distribution.
X5 = X3.copy()
X5['Fare_log'] = np.log1p(pd.to_numeric(X5['Fare'], errors='coerce'))

numeric_features5 = [c for c in numeric_features3 if c != 'Fare'] + ['Fare_log']
categorical_features5 = categorical_features3

# TODO preprocess5 + CV
preprocess5 = make_preprocess(numeric_features5, categorical_features5)
pipe5 = Pipeline(steps=[('preprocess', preprocess5), ('model', LogisticRegression(max_iter=5000))])
scores5 = cross_validate(pipe5, X5, y, cv=cv, scoring={'acc': 'accuracy'})
print('with Fare_log acc mean', np.mean(scores5['test_acc']))
# Out:
# with Fare_log acc mean 0.875

# %% [markdown]
# ## Section 5 — Interaction features
#
# ### Task 5.1: FamilySize and IsAlone
# FamilySize = SibSp + Parch + 1
# IsAlone = FamilySize == 1
#
# ### Task 5.2: Sex × Pclass cross
# Create a categorical cross feature like `Sex_Pclass`.
#
# # TODO: implement and evaluate.

# %%
X6 = X5.copy()
X6['FamilySize'] = pd.to_numeric(X6['SibSp'], errors='coerce').fillna(0) + pd.to_numeric(X6['Parch'], errors='coerce').fillna(0) + 1
X6['IsAlone'] = (X6['FamilySize'] == 1).astype(int)
X6['Sex_Pclass'] = X6['Sex'].astype(str) + '_P' + X6['Pclass'].astype(str)

numeric_features6 = numeric_features5 + ['FamilySize','IsAlone']
categorical_features6 = categorical_features5 + ['Sex_Pclass']

# TODO preprocess6 + CV
preprocess6 = make_preprocess(numeric_features6, categorical_features6)
pipe6 = Pipeline(steps=[('preprocess', preprocess6), ('model', LogisticRegression(max_iter=5000))])
scores6 = cross_validate(pipe6, X6, y, cv=cv, scoring={'acc': 'accuracy'})
print('with interactions acc mean', np.mean(scores6['test_acc']))
# Out:
# with interactions acc mean 0.625

# %% [markdown]
# ---
# ## Submission Checklist
# - Baseline pipeline + CV
# - Missingness indicators compared
# - Title feature added
# - Leakage explanation for target encoding
# - Nonlinear transform (Fare_log) evaluated
# - Interaction features evaluated
